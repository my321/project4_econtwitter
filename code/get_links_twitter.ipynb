# %%
from bs4 import BeautifulSoup
import requests
import json

# %% [markdown]
# ##### Use the profile links from repec to get twitter usernames

# %%
url = 'https://ideas.repec.org/f/pab367.html' 

response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
page=response.text

# %%
soup=BeautifulSoup(page, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Jorge Abad | IDEAS/RePEc
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="zimmermann@stlouisfed.org" name="author"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" rel="stylesheet"/>
#   <link href="/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="/css/normalnew.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/pushy.css" rel="stylesheet" type="text/css"/>
#   <link href="mailto:zimmermann@stlouisfed.org" rev="made"/>
#   <link href="/favicon.ico" rel="icon" type="image.jpg"/>
#   <!--[if lte IE 9]>
#   <script src="/css/html5shiv.min.js"></script>
#   <script src="/css/respond.min.js"></script>
# <![endif]-->
# ...

# %%
soup.find_all('table')
# Out:
# [<table class="table table-condensed">
#  <tbody>
#  <tr>
#  <td>First Name:</td><td>Jorge</td>
#  </tr><tr>
#  <td>Middle Name:</td><td></td>
#  </tr><tr>
#  <td>Last Name:</td><td>Abad</td>
#  </tr><tr>
#  <td>Suffix:</td><td></td>
#  </tr><tr>
#  <td>RePEc Short-ID:</td><td>pab367</td>
#  </tr><tr>
#  <td class="emaillabel"></td><td>
#  <span data-liame2='["es","edu","cemfi","m7i7","abad","jorge"]'></span></td></tr><tr>
#  <td class="homelabel"></td><td><a href="http://www.cemfi.es/~abad/" target="_blank">http://www.cemfi.es/~abad/  <i class="fa fa-external-link"></i></a></td>
#  </tr><tr>
#  <td class="postallabel"></td><td>Casado del Alisal 5 28014 Madrid, Spain</td>
#  </tr><tr>
#  <td class="phonelabel"></td><td>(+34) 914 290 551</td>
#  </tr><tr><td><a href="/i/etwitter.html">Twitter</a>:</td><td><a href="https://twitter.com/jrg_abad" target="_blank"><i class="fa fa-twitter"></i> @jrg_abad <i class="fa fa-external-link"></i></a></td>
#  </tr></tbody></table>]

# %% [markdown]
# ##### Find location of the twitter username using one profile page

# %%
handle=soup.find_all('table')[0].find(class_="fa fa-twitter").next
handle
# Out:
# ' @jrg_abad '

# %%
soup.find_all('table')[0].find(class_="fa fa-twitter").next
# Out:
# ' @jrg_abad '

# %%
handle.strip()
# Out:
# '@jrg_abad'

# %%
handle=handle.replace("@","")

# %%
handle=handle.strip()

# %%
handle
# Out:
# 'jrg_abad'

# %% [markdown]
# ##### Load in the profile urls

# %%
with open('repec_links.txt', 'r') as filehandle:
    links = json.load(filehandle)

# %%
# Out:
# ['/f/pab367.html',
#  '/f/pal867.html',
#  '/f/pan390.html',
#  '/e/pab127.html',
#  '/e/pal30.html',
#  '/e/pap38.html',
#  '/f/pab351.html',
#  '/f/pal847.html',
#  '/e/par133.html',
#  '/f/pab325.html',
#  '/f/pal720.html',
#  '/e/par39.html',
#  '/e/pab28.html',
#  '/f/pal649.html',
#  '/e/par149.html',
#  '/e/pab133.html',
#  '/f/pal663.html',
#  '/f/par290.html',
#  '/e/pac70.html',
#  '/f/pal370.html',
#  '/f/par401.html',
#  '/e/pac28.html',
#  '/f/pal714.html',
#  '/f/par432.html',
#  '/e/pad100.html',
#  '/e/pal9.html',
#  '/f/par339.html',
#  '/e/pad159.html',
#  '/e/pal39.html',
#  '/f/par416.html',
#  '/f/pad257.html',
#  '/f/pal673.html',
#  '/f/par444.html',
#  '/f/pad203.html',
#  '/f/pal376.html',
#  '/f/par370.html',
#  '/e/pad152.html',
#  '/f/pal829.html',
#  '/e/par20.html',
#  '/f/pad243.html',
#  '/f/pal497.html',
#  '/f/par395.html',
#  '/e/pad164.html',
#  '/e/pam5.html',
#  '/f/par337.html',
#  '/e/pad123.html',
#  '/f/pba1757.html',
#  '/e/par184.html',
# ...

# %%
# links=['/f/pab367.html',
#  '/f/pal867.html',
#  '/f/pan390.html',
#  '/e/pab127.html',
#  '/e/pal30.html',
#  '/e/pap38.html',
#  '/f/pab351.html',
#  '/f/pal847.html',
#  '/e/par133.html',
#  '/f/pab325.html',
#  '/f/pal720.html',
#  '/e/par39.html',
#  '/e/pab28.html',
#  '/f/pal649.html',
#  '/e/par149.html',
#  '/e/pab133.html',
#  '/f/pal663.html',
#  '/f/par290.html',
#  '/e/pac70.html',
#  '/f/pal370.html',
#  '/f/par401.html',
#  '/e/pac28.html',
#  '/f/pal714.html',
#  '/f/par432.html',
#  '/e/pad100.html']

# %% [markdown]
# ##### LOOP THROUGH LIST OF URLS TO GRAB ALL THE TWITTER USERNAME

# %%
twitter_usernames=[]
for link in links: 
    url = 'https://ideas.repec.org'+link 
    response = requests.get(url)
    page=response.text
    soup=BeautifulSoup(page, 'lxml')
    handle=soup.find_all('table')[0].find(class_="fa fa-twitter").next
    handle=handle.replace("@","")
    handle=handle.strip()
    twitter_usernames.append(handle)

# %%
len(twitter_usernames)
# Out:
# 2020

# %% [markdown]
# ##### SAVE LIST OF TWITTER USERNAMES

# %%
with open('twitter_usernames.txt', 'w') as filehandle:
    json.dump(twitter_usernames, filehandle)

# %% [markdown]
# ##### Scratchwork

# %%
link='/f/pal867.html'

# %%
url = 'https://ideas.repec.org'+link

# %%
url
# Out:
# 'https://ideas.repec.org/f/pal867.html'

# %%
response = requests.get(url)
page=response.text
soup=BeautifulSoup(page, 'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <title>\n   Jorge Abad | IDEAS/RePEc\n  </title>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="zimmermann@stlouisfed.org" name="author"/>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" rel="stylesheet"/>\n  <link href="/css/font-awesome.min.css" rel="stylesheet"/>\n  <link href="/css/normalnew.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/pushy.css" rel="stylesheet" type="text/css"/>\n  <link href="mailto:zimmermann@stlouisfed.org" rev="made"/>\n  <link href="/favicon.ico" rel="icon" type="image.jpg"/>\n  <!--[if lte IE 9]>\n  <script src="/css/html5shiv.min.js"></script>\n  <script src="/css/respond.min.js"></script>\n<![endif]-->\n  <meta content="Jorge Abad
# ...

# %%
handle=soup.find_all('table')[0].find(class_="fa fa-twitter").next
handle=handle.replace("@","")
handle=handle.strip()

# %%
handle
# Out:
# 'jrg_abad'
